# %%
import altair as alt
import numpy as np
import pandas as pd

# %%
knowledge_data= pd.read_excel("data/user_model.xls", 2, usecols="A:F")
knowledge_data.columns=knowledge_data.columns.astype(str)
knowledge_data=knowledge_data.rename(columns={" UNS": "level"})
knowledge_data
# Out:
#       STG   SCG   STR   LPR   PEG     level
# 0    0.00  0.10  0.50  0.26  0.05  Very Low
# 1    0.05  0.05  0.55  0.60  0.14       Low
# 2    0.08  0.18  0.63  0.60  0.85      High
# 3    0.20  0.20  0.68  0.67  0.85      High
# 4    0.22  0.22  0.90  0.30  0.90      High
# ..    ...   ...   ...   ...   ...       ...
# 140  0.90  0.78  0.62  0.32  0.89      High
# 141  0.85  0.82  0.66  0.83  0.83      High
# 142  0.56  0.60  0.77  0.13  0.32       Low
# 143  0.66  0.68  0.81  0.57  0.57    Middle
# 144  0.68  0.64  0.79  0.97  0.24    Middle
#
# [145 rows x 6 columns]

# %%
plot=(
    alt.Chart(knowledge_data)
    .mark_point()
    .encode(
        x=alt.X("LPR", title="study level"),
        y=alt.Y("STG", title= "performance"),
        color="level"
    )
)
plot
# Out:
# /opt/conda/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
hear_disease=pd.read_csv("data/switzerland.data")
hear_disease
# Out:
#             3001 0 65 1 1 1 1
# 0       -9 4 115 0 0 -9 -9 -9
# 1          0 -9 -9 0 1 9 85 0
# 2       1 1 0 1 12 8.3 -9 100
# 3     93 56 185 80 115 70 1 0
# 4       0 2 -9 -9 -9 -9 -9 -9
# ...                       ...
# 1224   0 -9 -9 -9 -9 -9 -9 -9
# 1225      -9 -9 -9 7 1 0 -9 7
# 1226         4 85 1 1 1 1 1 1
# 1227          1 1 1 2 1 1 1 1
# 1228          1 1 70 -9. name
#
# [1229 rows x 1 columns]
